# %% [markdown]
# <a href="https://colab.research.google.com/github/Anoop045/Assignment1/blob/main/Assign1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
column=['Class Name','Left-Weight','Left-Distance','Right-Weight','Right-Distance']

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/balance-scale/balance-scale.data",names=column)

# %%
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  Mean
# 0            B            1              1             1               1     0
# 1            R            1              1             1               2     1
# 2            R            1              1             1               3     2
# 3            R            1              1             1               4     3
# 4            R            1              1             1               5     4
# ..         ...          ...            ...           ...             ...   ...
# 620          L            5              5             5               1   620
# 621          L            5              5             5               2   621
# 622          L            5              5             5               3   622
# 623          L            5              5             5               4   623
# 624          B            5              5             5               5   624
#
# [625 rows x 6 columns]

# %%
df['Class Name'].unique()
# Out:
# array(['B', 'R', 'L'], dtype=object)

# %%
df['Left-Weight'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Left-Distance'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Right-Weight'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Right-Distance'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
df.dtypes
# Out:
# Class Name        object
# Left-Weight        int64
# Left-Distance      int64
# Right-Weight       int64
# Right-Distance     int64
# dtype: object

# %%
df.describe()
# Out:
#        Left-Weight  Left-Distance  Right-Weight  Right-Distance
# count   625.000000     625.000000    625.000000      625.000000
# mean      3.000000       3.000000      3.000000        3.000000
# std       1.415346       1.415346      1.415346        1.415346
# min       1.000000       1.000000      1.000000        1.000000
# 25%       2.000000       2.000000      2.000000        2.000000
# 50%       3.000000       3.000000      3.000000        3.000000
# 75%       4.000000       4.000000      4.000000        4.000000
# max       5.000000       5.000000      5.000000        5.000000

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Left-Weight       3.0
# Left-Distance     3.0
# Right-Weight      3.0
# Right-Distance    3.0
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 0      1.00
# 1      1.25
# 2      1.50
# 3      1.75
# 4      2.00
#        ...
# 620    4.00
# 621    4.25
# 622    4.50
# 623    4.75
# 624    5.00
# Length: 625, dtype: float64

# %%
df.count
# Out:
# <bound method DataFrame.count of     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]>

# %%
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
df['Mean']=[i for i in range(625)]
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  Mean
# 0            B            1              1             1               1     0
# 1            R            1              1             1               2     1
# 2            R            1              1             1               3     2
# 3            R            1              1             1               4     3
# 4            R            1              1             1               5     4
# ..         ...          ...            ...           ...             ...   ...
# 620          L            5              5             5               1   620
# 621          L            5              5             5               2   621
# 622          L            5              5             5               3   622
# 623          L            5              5             5               4   623
# 624          B            5              5             5               5   624
#
# [625 rows x 6 columns]

# %%
df1=df.rename(columns={'Mean':'Index'})

# %%
df1
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Index
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ..     ...
# ...

# %%
df1=df1.drop(['Index'],axis=1)

# %%
df1
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
df1['Total_weight']=df1['Left-Weight']+df1['Right-Weight']
df1
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_weight
# 0               2
# 1               2
# 2               2
# ...

# %%
df1.isnull()
# Out:
#      Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0         False        False          False         False           False
# 1         False        False          False         False           False
# 2         False        False          False         False           False
# 3         False        False          False         False           False
# 4         False        False          False         False           False
# ..          ...          ...            ...           ...             ...
# 620       False        False          False         False           False
# 621       False        False          False         False           False
# 622       False        False          False         False           False
# 623       False        False          False         False           False
# 624       False        False          False         False           False
#
#      Total_weight
# 0           False
# 1           False
# 2           False
# ...

# %%
df1['Test']=[i**2 for i in range(625)]
df1
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_weight    Test
# 0               2       0
# 1               2       1
# ...

# %%
df1.isnull().sum()
# Out:
# Class Name        0
# Left-Weight       0
# Left-Distance     0
# Right-Weight      0
# Right-Distance    0
# Total_weight      0
# Test              0
# dtype: int64

# %%
df1
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_weight    Test
# 0               2       0
# 1               2       1
# ...

# %%
df1.iloc[0:3]
# Out:
#   Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0          B            1              1             1               1
# 1          R            1              1             1               2
# 2          R            1              1             1               3
#
#    Total_weight  Test
# 0             2     0
# 1             2     1
# 2             2     4

# %%
df1.iloc[2,4]
# Out:
# 3

# %%
df1.iloc[:,1:4]
# Out:
#      Left-Weight  Left-Distance  Right-Weight
# 0              1              1             1
# 1              1              1             1
# 2              1              1             1
# 3              1              1             1
# 4              1              1             1
# ..           ...            ...           ...
# 620            5              5             5
# 621            5              5             5
# 622            5              5             5
# 623            5              5             5
# 624            5              5             5
#
# [625 rows x 3 columns]

# %%
df1.loc[df1.Test<=400]
# Out:
#    Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0           B            1              1             1               1
# 1           R            1              1             1               2
# 2           R            1              1             1               3
# 3           R            1              1             1               4
# 4           R            1              1             1               5
# 5           R            1              1             2               1
# 6           R            1              1             2               2
# 7           R            1              1             2               3
# 8           R            1              1             2               4
# 9           R            1              1             2               5
# 10          R            1              1             3               1
# 11          R            1              1             3               2
# ...

# %%
df1.loc[df1.Test<=200,['Class Name','Total_weight','Test']]
# Out:
#    Class Name  Total_weight  Test
# 0           B             2     0
# 1           R             2     1
# 2           R             2     4
# 3           R             2     9
# 4           R             2    16
# 5           R             3    25
# 6           R             3    36
# 7           R             3    49
# 8           R             3    64
# 9           R             3    81
# 10          R             4   100
# 11          R             4   121
# 12          R             4   144
# 13          R             4   169
# 14          R             4   196

# %%
df1['dummy']=10
df1
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_weight    Test  dummy
# 0               2       0     10
# ...
